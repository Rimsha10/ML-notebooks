# %%
# @title
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ipywidgets as widgets
from IPython.display import display

# %%
# @title
from google.colab import drive
drive.mount('/content/drive')

# %%
# @title
# load the model from disk
model1_lin_reg = pickle.load(open('/content/drive/MyDrive/MovieRev/lin_reg_model_movierev', 'rb'))
poly2_reg = pickle.load(open('/content/drive/MyDrive/MovieRev/poly2_reg_model_movierev', 'rb'))
poly3_reg = pickle.load(open('/content/drive/MyDrive/MovieRev/poly3_reg_model_movierev', 'rb'))

# %%
# @title
X_train=np.load('/content/drive/MyDrive/MovieRev/xtrain.npy')
X_test=np.load('/content/drive/MyDrive/MovieRev/xtest.npy')
Y_train=np.load('/content/drive/MyDrive/MovieRev/ytrain.npy')
Y_test=np.load('/content/drive/MyDrive/MovieRev/xtest.npy')
X_train_poly1=np.load('/content/drive/MyDrive/MovieRev/xtrainpoly2.npy')
X_test_poly1=np.load('/content/drive/MyDrive/MovieRev/xtestpoly2.npy')
X_train_poly=np.load('/content/drive/MyDrive/MovieRev/xtrainpoly3.npy')
X_test_poly=np.load('/content/drive/MyDrive/MovieRev/xtestpoly3.npy')

# %% [markdown]
# ![1_DywgVk0WQX66Io_boucHwA.jpg](data:image/jpeg;base64,...)

# %%
button = widgets.Button(description="Enter")
output = widgets.Output()

def on_button_clicked(b):
  # Display the message within the output widget.
  with output:
    if Algorithm=='Linear Regression':
      y=model1_lin_reg.predict(pd.DataFrame([Production_Budget]))
    elif Algorithm=="Polynomial Regression(deg=2)":
      y=poly2_reg.predict(pd.DataFrame([[Production_Budget,Production_Budget**2]]))
    elif Algorithm=="Polynomial Regression(deg=3)":
      y=poly2_reg.predict(pd.DataFrame([[Production_Budget,Production_Budget**2,Production_Budget**3]]))
    print("Worldwide_Gross: ",y[0][0])

button.on_click(on_button_clicked)
# @title Movie Revenue Predictor { run: "auto", vertical-output: true, display-mode: "form" }
Production_Budget = 5000000 # @param {type:"number"}
Algorithm = 'Polynomial Regression(deg=2)' # @param ["Linear Regression", "Polynomial Regression(deg=2)","Polynomial Regression(deg=3)"]
display(button, output)
