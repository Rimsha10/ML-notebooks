# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Create

# %% [markdown]
# ### 1.1 Create from a CSV

# %%
df = pd.read_csv('telco_churn.csv')

# %% [markdown]
# ### 1.2 Create from a Dictionary

# %%
tempdict = {'col1':[1,2,3], 'col2':[4,5,6], 'col3':[7,8,9]}

# %%
dictdf = pd.DataFrame.from_dict(tempdict)

# %% [markdown]
# # 2. Read

# %% [markdown]
# ### 2.1 Show Top 5 and Bottom 5 Rows

# %%
df.head(10)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    LA             117        408                 No              No
# 9    WV             141        415                Yes             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# ...

# %%
dictdf.head()
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
df.tail(15)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3318    OK              52        415                 No              No
# 3319    WY              89        415                 No              No
# 3320    GA             122        510                Yes              No
# 3321    VT              60        415                 No              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
# 3324    WV             159        415                 No              No
# 3325    OH              78        408                 No              No
# 3326    OH              96        415                 No              No
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# ...

# %% [markdown]
# ### 2.2 Show Columns and Data Type

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# State                      object
# Account length              int64
# Area code                   int64
# International plan         object
# Voice mail plan            object
# Number vmail messages       int64
# Total day minutes         float64
# Total day calls           float64
# Total day charge          float64
# Total eve minutes         float64
# Total eve calls           float64
# Total eve charge          float64
# Total night minutes       float64
# Total night calls         float64
# Total night charge        float64
# Total intl minutes        float64
# Total intl calls            int64
# Total intl charge         float64
# Customer service calls    float64
# Churn                      object
# dtype: object

# %% [markdown]
# ### 2.3 Summary Statistics

# %%
df.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3323.000000
# mean       101.064806   437.182418               8.099010         179.787150
# std         39.822106    42.371290              13.688365          54.419625
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.500000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3323.000000       3315.000000        3324.000000      3325.000000
# mean        100.456214         30.557831         201.033935       100.110677
# ...

# %%
df.describe(include='object')
# Out:
#        State International plan Voice mail plan  Churn
# count   3333               3333            3333   3325
# unique    51                  2               2      2
# top       WV                 No              No  False
# freq     106               3010            2411   2842

# %% [markdown]
# ### 2.4 Filtering Columns

# %%
df.State
# Out:
# 0       KS
# 1       OH
# 2       NJ
# 3       OH
# 4       OK
#         ..
# 3328    AZ
# 3329    WV
# 3330    RI
# 3331    CT
# 3332    TN
# Name: State, Length: 3333, dtype: object

# %%
df['International plan']
# Out:
# 0        No
# 1        No
# 2        No
# 3       Yes
# 4       Yes
#        ...
# 3328     No
# 3329     No
# 3330     No
# 3331    Yes
# 3332     No
# Name: International plan, Length: 3333, dtype: object

# %%
df[['State', 'International plan']]
# Out:
#      State International plan
# 0       KS                 No
# 1       OH                 No
# 2       NJ                 No
# 3       OH                Yes
# 4       OK                Yes
# ...    ...                ...
# 3328    AZ                 No
# 3329    WV                 No
# 3330    RI                 No
# 3331    CT                Yes
# 3332    TN                 No
#
# [3333 rows x 2 columns]

# %%
df.Churn.unique()
# Out:
# array([False, nan, True], dtype=object)

# %% [markdown]
# ### 2.5 Filtering on Rows

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4             99.0             16.78
# ...

# %%
df[df['International plan']=='No']
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 6       MA             121        510                 No             Yes
# 8       LA             117        408                 No              No
# ...    ...             ...        ...                ...             ...
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df[(df['International plan']=='No') & (df['Churn']==True)]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 10      IN              65        415                 No              No
# 15      NY             161        415                 No              No
# 21      CO              77        408                 No              No
# 33      AZ              12        408                 No              No
# 48      ID             119        415                 No              No
# ...    ...             ...        ...                ...             ...
# 3280    AR              76        408                 No              No
# 3287    KS             170        415                 No             Yes
# 3301    CA              84        415                 No              No
# 3322    MD              62        408                 No              No
# 3323    IN             117        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# ### 2.6 Indexing with iloc

# %%
df.iloc[14]
# Out:
# State                        IA
# Account length               62
# Area code                   415
# International plan           No
# Voice mail plan              No
# Number vmail messages         0
# Total day minutes           NaN
# Total day calls             NaN
# Total day charge            NaN
# Total eve minutes         307.2
# Total eve calls              76
# Total eve charge          26.11
# Total night minutes         203
# Total night calls            99
# Total night charge         9.14
# Total intl minutes         13.1
# Total intl calls              6
# Total intl charge          3.54
# Customer service calls        4
# Churn                     False
# Name: 14, dtype: object

# %%
df.iloc[14,-1]
# Out:
# False

# %%
df.iloc[22:33]
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 22    AZ             130        415                 No              No
# 23    SC             111        415                 No              No
# 24    VA             132        510                 No              No
# 25    NE             174        415                 No              No
# 26    WY              57        408                 No             Yes
# 27    MT              54        408                 No              No
# 28    MO              20        415                 No              No
# 29    HI              49        510                 No              No
# 30    IL             142        415                 No              No
# 31    NH              75        510                 No              No
# 32    LA             172        408                 No              No
#
#     Number vmail messages  Total day minutes  Total day calls  \
# ...

# %% [markdown]
# ### 2.7 Indexing with loc

# %%
state = df.copy()
state.set_index('State', inplace=True)

# %%
state.head()
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# KS                128        415                 No             Yes
# OH                107        415                 No             Yes
# NJ                137        415                 No              No
# OH                 84        408                Yes              No
# OK                 75        415                Yes              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# KS                        25              265.1            110.0
# OH                        26              161.6            123.0
# NJ                         0              243.4            114.0
# OH                         0              299.4             71.0
# OK                         0              166.7            113.0
#
#        Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# State
# ...

# %%
state.loc['OH']
# Out:
#        Account length  Area code International plan Voice mail plan  \
# State
# OH                107        415                 No             Yes
# OH                 84        408                Yes              No
# OH                 65        408                 No              No
# OH                 83        415                 No              No
# OH                 63        415                Yes             Yes
# ...               ...        ...                ...             ...
# OH                160        415                 No              No
# OH                 88        408                 No              No
# OH                106        415                 No             Yes
# OH                 78        408                 No              No
# OH                 96        415                 No              No
#
#        Number vmail messages  Total day minutes  Total day calls  \
# State
# OH                        26              161.6            123.0
# ...

# %% [markdown]
# # 3. Update

# %% [markdown]
# ### 3.1 Dropping Rows

# %%
df.isnull().sum()
# Out:
# State                      0
# Account length             0
# Area code                  0
# International plan         0
# Voice mail plan            0
# Number vmail messages      0
# Total day minutes         10
# Total day calls           10
# Total day charge          18
# Total eve minutes          9
# Total eve calls            8
# Total eve charge           0
# Total night minutes        0
# Total night calls          1
# Total night charge         0
# Total intl minutes         0
# Total intl calls           0
# Total intl charge          5
# Customer service calls     5
# Churn                      8
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# ### 3.2 Dropping Columns

# %%
df.drop('Area code', axis=1)
# Out:
#      State  Account length International plan Voice mail plan  \
# 0       KS             128                 No             Yes
# 1       OH             107                 No             Yes
# 2       NJ             137                 No              No
# 3       OH              84                Yes              No
# 4       OK              75                Yes              No
# ...    ...             ...                ...             ...
# 3328    AZ             192                 No             Yes
# 3329    WV              68                 No              No
# 3330    RI              28                 No              No
# 3331    CT             184                Yes              No
# 3332    TN              74                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1            110.0
# 1                        26              161.6            123.0
# ...

# %% [markdown]
# ### 3.3 Creating Calculated Columns

# %%
df['New Column'] = df['Total night minutes'] + df['Total intl minutes']

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %% [markdown]
# ### 3.4 Updating an Entire Column

# %%
df['New Column'] = 100

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %% [markdown]
# ### 3.5 Updating a Single Value

# %%
df.iloc[0,-1] = 10

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1            110.0
# 1                     26              161.6            123.0
# 2                      0              243.4            114.0
# 3                      0              299.4             71.0
# 4                      0              166.7            113.0
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# ...

# %% [markdown]
# ### 3.6 Condition based Updating using Apply

# %%
df['Churn Binary'] = df['Churn'].apply(lambda x: 1 if x==True else 0)

# %%
df[df['Churn']==True].head()
# Out:
#    State  Account length  Area code International plan Voice mail plan  \
# 10    IN              65        415                 No              No
# 41    MD             135        408                Yes             Yes
# 48    ID             119        415                 No              No
# 54    WY              87        415                 No              No
# 57    CO             121        408                 No             Yes
#
#     Number vmail messages  Total day minutes  Total day calls  \
# 10                      0              129.1            137.0
# 41                     41              173.1             85.0
# 48                      0              159.1            114.0
# 54                      0              151.0             83.0
# 57                     30              198.4            129.0
#
#     Total day charge  Total eve minutes  ...  Total night minutes  \
# 10             21.95              228.5  ...                208.8
# ...

# %% [markdown]
# # 4. Delete/Output

# %% [markdown]
# ### 4.1 Output to CSV

# %%
df.to_csv('output.csv')

# %% [markdown]
# ### 4.2 Output to JSON

# %%
df.to_json()

# %% [markdown]
# ### 4.3 Output to HTML

# %%
df.to_html()

# %% [markdown]
# ### 4.4 Delete a DataFrame

# %%
del df

# %%
#Q2
Location=['United States','India','Brazil','Russia','United Kingdom','France','Spain','Italy','Turkey','Germany']
Deaths=[517204,156938,254263,86122,122705,86332,69142,97507,28503,70601]
Recovered=[np.nan,10763451,9386440,3811797,np.nan,np.nan,np.nan,2398352,2565723,2242767]
Cases=[28833039,11079979,10517232,4246079,4170519,3736016,3188553,2907825,2693164,2444169]

# %%
s1=pd.Series('Location')
s2=pd.Series('Deaths')
s3=pd.Series('Cases')
s4=pd.Series('Recovered')

# %%
df2=pd.DataFrame.from_dict({'Location':Location ,'Cases':Cases,'Deaths':Deaths,'Recovered':Recovered})
df2
# Out:
#          Location     Cases  Deaths   Recovered
# 0   United States  28833039  517204         NaN
# 1           India  11079979  156938  10763451.0
# 2          Brazil  10517232  254263   9386440.0
# 3          Russia   4246079   86122   3811797.0
# 4  United Kingdom   4170519  122705         NaN
# 5          France   3736016   86332         NaN
# 6           Spain   3188553   69142         NaN
# 7           Italy   2907825   97507   2398352.0
# 8          Turkey   2693164   28503   2565723.0
# 9         Germany   2444169   70601   2242767.0

# %%
pd.Series(df2['Cases'])
# Out:
# 0    28833039
# 1    11079979
# 2    10517232
# 3     4246079
# 4     4170519
# 5     3736016
# 6     3188553
# 7     2907825
# 8     2693164
# 9     2444169
# Name: Cases, dtype: int64

# %%
updtated_df=df2.copy()

# %%
#Q3
def condition(x):
    if x<3000000:
       return 'low'
    elif 4000000>x>3000000:
       return "medium"
    else:
       return"high"

# %%
updtated_df['Status']=updtated_df['Cases'].apply(condition)
updtated_df
# Out:
#          Location     Cases  Deaths   Recovered  Status
# 0   United States  28833039  517204         NaN    high
# 1           India  11079979  156938  10763451.0    high
# 2          Brazil  10517232  254263   9386440.0    high
# 3          Russia   4246079   86122   3811797.0    high
# 4  United Kingdom   4170519  122705         NaN    high
# 5          France   3736016   86332         NaN  medium
# 6           Spain   3188553   69142         NaN  medium
# 7           Italy   2907825   97507   2398352.0     low
# 8          Turkey   2693164   28503   2565723.0     low
# 9         Germany   2444169   70601   2242767.0     low

# %%
#Q4
sorted_by_Deaths=updtated_df.sort_values('Deaths',ascending=True,ignore_index=True)
sorted_by_Deaths
# Out:
#          Location     Cases  Deaths   Recovered  Status
# 0          Turkey   2693164   28503   2565723.0     low
# 1           Spain   3188553   69142         NaN  medium
# 2         Germany   2444169   70601   2242767.0     low
# 3          Russia   4246079   86122   3811797.0    high
# 4          France   3736016   86332         NaN  medium
# 5           Italy   2907825   97507   2398352.0     low
# 6  United Kingdom   4170519  122705         NaN    high
# 7           India  11079979  156938  10763451.0    high
# 8          Brazil  10517232  254263   9386440.0    high
# 9   United States  28833039  517204         NaN    high

# %%
sorted_Series=pd.Series(Deaths).sort_values(ascending=True)
sorted_Series
# Out:
# 8     28503
# 6     69142
# 9     70601
# 3     86122
# 5     86332
# 7     97507
# 4    122705
# 1    156938
# 2    254263
# 0    517204
# dtype: int64

# %%
sorted_Series=pd.Series(Deaths).rank(ascending=True)
sorted_Series
# Out:
# 0    10.0
# 1     8.0
# 2     9.0
# 3     4.0
# 4     7.0
# 5     5.0
# 6     2.0
# 7     6.0
# 8     1.0
# 9     3.0
# dtype: float64

# %%
rankdf=updtated_df.copy()
rankdf['Deaths Count']=rankdf['Deaths'].rank(ascending=True)
rankdf
# Out:
#          Location     Cases  Deaths   Recovered  Status  Deaths Count
# 0   United States  28833039  517204         NaN    high          10.0
# 1           India  11079979  156938  10763451.0    high           8.0
# 2          Brazil  10517232  254263   9386440.0    high           9.0
# 3          Russia   4246079   86122   3811797.0    high           4.0
# 4  United Kingdom   4170519  122705         NaN    high           7.0
# 5          France   3736016   86332         NaN  medium           5.0
# 6           Spain   3188553   69142         NaN  medium           2.0
# 7           Italy   2907825   97507   2398352.0     low           6.0
# 8          Turkey   2693164   28503   2565723.0     low           1.0
# 9         Germany   2444169   70601   2242767.0     low           3.0

# %%
#Q5
df2.describe()
# Out:
#               Cases         Deaths     Recovered
# count  1.000000e+01      10.000000  6.000000e+00
# mean   7.381658e+06  148931.700000  5.194755e+06
# std    8.172197e+06  143366.103826  3.845493e+06
# min    2.444169e+06   28503.000000  2.242767e+06
# 25%    2.978007e+06   74481.250000  2.440195e+06
# 50%    3.953268e+06   91919.500000  3.188760e+06
# 75%    8.949444e+06  148379.750000  7.992779e+06
# max    2.883304e+07  517204.000000  1.076345e+07

# %%
df2.describe(include='object')
# Out:
#              Location
# count              10
# unique             10
# top     United States
# freq                1

# %%
pd.Series(Recovered).describe()
# Out:
# count    6.000000e+00
# mean     5.194755e+06
# std      3.845493e+06
# min      2.242767e+06
# 25%      2.440195e+06
# 50%      3.188760e+06
# 75%      7.992779e+06
# max      1.076345e+07
# dtype: float64

# %%
#Q5
df4=updtated_df.copy()
df4.count()
# Out:
# Location     10
# Cases        10
# Deaths       10
# Recovered     6
# Status       10
# dtype: int64

# %%
pd.Series(Recovered).count()
# Out:
# 6

# %%
df4.mean(numeric_only=None)
# Out:
# C:\Users\Huma\AppData\Local\Temp\ipykernel_4100\1308279225.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df4.mean(numeric_only=None)
# Cases        7381657.5
# Deaths        148931.7
# Recovered    5194755.0
# dtype: float64

# %%
df4.median(numeric_only=None)
# Out:
# C:\Users\Huma\AppData\Local\Temp\ipykernel_4100\3254786010.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df4.median()
# Cases        3953267.5
# Deaths         91919.5
# Recovered    3188760.0
# dtype: float64

# %%
df4.min()
# Out:
# Location        Brazil
# Cases          2444169
# Deaths           28503
# Recovered    2242767.0
# Status            high
# dtype: object

# %%
df4.max()
# Out:
# Location     United States
# Cases             28833039
# Deaths              517204
# Recovered       10763451.0
# Status              medium
# dtype: object

# %%
pd.Series(Deaths).argmin()
# Out:
# 8

# %%
pd.Series(Deaths).argmax()
# Out:
# 0

# %%
pd.Series(Cases).idxmin()
# Out:
# 9

# %%
pd.Series(Cases).idxmax()
# Out:
# 0

# %%
df4.quantile()
# Out:
# Cases        3953267.5
# Deaths         91919.5
# Recovered    3188760.0
# Name: 0.5, dtype: float64

# %%
df4.isnull().sum()
# Out:
# Location     0
# Cases        0
# Deaths       0
# Recovered    4
# Status       0
# dtype: int64

# %%
df4.mad()
# Out:
# Cases        5.657056e+06
# Deaths       9.632198e+04
# Recovered    3.253460e+06
# dtype: float64

# %%
df4.var()
# Out:
# C:\Users\Huma\AppData\Local\Temp\ipykernel_4100\3198849812.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df4.var()
# Cases        6.678480e+13
# Deaths       2.055384e+10
# Recovered    1.478782e+13
# dtype: float64

# %%
df4.std()
# Out:
# C:\Users\Huma\AppData\Local\Temp\ipykernel_4100\2777016802.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df4.std()
# Cases        8.172197e+06
# Deaths       1.433661e+05
# Recovered    3.845493e+06
# dtype: float64

# %%
df4.skew()
# Out:
# C:\Users\Huma\AppData\Local\Temp\ipykernel_4100\4174566864.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df4.skew()
# Cases        2.405693
# Deaths       2.249842
# Recovered    0.938662
# dtype: float64

# %%
df4.kurt()
# Out:
# C:\Users\Huma\AppData\Local\Temp\ipykernel_4100\3774221498.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df4.kurt()
# Cases        6.142260
# Deaths       5.396014
# Recovered   -1.580094
# dtype: float64

# %%
df4.select_dtypes(include='number').cumsum()
# Out:
#       Cases   Deaths   Recovered
# 0  28833039   517204         NaN
# 1  39913018   674142  10763451.0
# 2  50430250   928405  20149891.0
# 3  54676329  1014527  23961688.0
# 4  58846848  1137232         NaN
# 5  62582864  1223564         NaN
# 6  65771417  1292706         NaN
# 7  68679242  1390213  26360040.0
# 8  71372406  1418716  28925763.0
# 9  73816575  1489317  31168530.0

# %%
df4.select_dtypes(include='number').cummin()
# Out:
#       Cases  Deaths   Recovered
# 0  28833039  517204         NaN
# 1  11079979  156938  10763451.0
# 2  10517232  156938   9386440.0
# 3   4246079   86122   3811797.0
# 4   4170519   86122         NaN
# 5   3736016   86122         NaN
# 6   3188553   69142         NaN
# 7   2907825   69142   2398352.0
# 8   2693164   28503   2398352.0
# 9   2444169   28503   2242767.0

# %%
df4.select_dtypes(include='number').cummax()
# Out:
#       Cases  Deaths   Recovered
# 0  28833039  517204         NaN
# 1  28833039  517204  10763451.0
# 2  28833039  517204  10763451.0
# 3  28833039  517204  10763451.0
# 4  28833039  517204         NaN
# 5  28833039  517204         NaN
# 6  28833039  517204         NaN
# 7  28833039  517204  10763451.0
# 8  28833039  517204  10763451.0
# 9  28833039  517204  10763451.0

# %%
df4.select_dtypes(include='number').cumprod()
# Out:
#                  Cases               Deaths     Recovered
# 0             28833039               517204           NaN
# 1      319469466626181          81168961352  1.076345e+07
# 2  2627076008664456880    20638263620243576  1.010305e+14
# 3  7683677728832826704  6521108426500297136  3.851077e+20
# 4 -3530367059382959568  8191788419739625648           NaN
# 5  6426695010879796992  2203555084571588928           NaN
# 6 -3145159625427226880  6546352681614863232           NaN
# 7  8329288016626499328  2525743648854594176  9.236238e+26
# 8 -6052080537096891392 -6370896385882158720  2.369763e+33
# 9  7311223601537315840 -4694990406290737792  5.314826e+39

# %%
pd.Series(Cases).pct_change()
# Out:
# 0         NaN
# 1   -0.615719
# 2   -0.050790
# 3   -0.596274
# 4   -0.017795
# 5   -0.104184
# 6   -0.146537
# 7   -0.088042
# 8   -0.073822
# 9   -0.092454
# dtype: float64

# %%
pd.Series(Deaths).diff()
# Out:
# 0         NaN
# 1   -360266.0
# 2     97325.0
# 3   -168141.0
# 4     36583.0
# 5    -36373.0
# 6    -17190.0
# 7     28365.0
# 8    -69004.0
# 9     42098.0
# dtype: float64

# %%
#Q6
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Location   10 non-null     object
#  1   Cases      10 non-null     int64
#  2   Deaths     10 non-null     int64
#  3   Recovered  6 non-null      float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 448.0+ bytes

# %%
#Q6
df6=df2.select_dtypes(include='number')
df6
# Out:
#       Cases  Deaths   Recovered
# 0  28833039  517204         NaN
# 1  11079979  156938  10763451.0
# 2  10517232  254263   9386440.0
# 3   4246079   86122   3811797.0
# 4   4170519  122705         NaN
# 5   3736016   86332         NaN
# 6   3188553   69142         NaN
# 7   2907825   97507   2398352.0
# 8   2693164   28503   2565723.0
# 9   2444169   70601   2242767.0

# %%
df6_cols=df6.columns
df6_cols
# Out:
# Index(['Cases', 'Deaths', 'Recovered'], dtype='object')

# %%
for i in df6_cols:
    df6[i].fillna(df6[i].mean(),inplace=True)
df6
# Out:
#       Cases  Deaths   Recovered
# 0  28833039  517204   5194755.0
# 1  11079979  156938  10763451.0
# 2  10517232  254263   9386440.0
# 3   4246079   86122   3811797.0
# 4   4170519  122705   5194755.0
# 5   3736016   86332   5194755.0
# 6   3188553   69142   5194755.0
# 7   2907825   97507   2398352.0
# 8   2693164   28503   2565723.0
# 9   2444169   70601   2242767.0
